# %% [markdown]
# # Quick Start: Lessons Dashboard
#
# This is the graphical root for the curriculum.
#
# ## Start Here
#
# | Area | Purpose | Open |
# |---|---|---|
# | 2026 Ecosystem | Modern multi-library tracks (LangChain, LiteLLM, LlamaIndex, DSPy, Agent CLIs, OpenClaw). | [Open 2026 Ecosystem](2026/00-ecosystem-index.ipynb) |
# | 2026 LangChain (Modern) | Runnable/LCEL-first LangChain lessons. | [Open 2026 LangChain](2026/langchain/00-modern-track-index.ipynb) |
# | Classic LangChain | Legacy/classic lessons for comparison. | [Open Classic](classic/00-classic-track-index.ipynb) |
#
# ## Click-Through Flow
#
# 1. Launcher tile: `Lessons Home`.
# 2. Pick a track from this page or from the 2026 ecosystem page.
# 3. Open a track index and click directly into each lesson notebook.
#
# ## Stable Paths
#
# All links resolve under `/lessons` in the Jupyter workspace mount.
#
# ## Next Step
#
# Continue to [2026 Ecosystem Index](2026/00-ecosystem-index.ipynb).
