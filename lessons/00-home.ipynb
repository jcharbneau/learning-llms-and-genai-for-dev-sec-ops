# %% [markdown]
# # Lessons Home
#
# Use this page as the launch point for all tracks.
#
# ## Recommended Entry Points
# - [2026 Ecosystem Index](2026/00-ecosystem-index.ipynb)
# - [2026 LangChain Modern Index](2026/langchain/00-modern-track-index.ipynb)
# - [Classic LangChain Index](classic/00-classic-track-index.ipynb)
#
# ## 2026 Tracks
# - [LiteLLM](2026/litellm/00-track-index.ipynb)
# - [LlamaIndex](2026/llamaindex/00-track-index.ipynb)
# - [DSPy](2026/dspy/00-track-index.ipynb)
# - [Agent CLIs](2026/agent-clis/00-track-index.ipynb)
#
# ## Classic Track Areas
# - [Developer](classic/developer/)
# - [Operations](classic/operations/)
# - [Quality](classic/quality/)
# - [Security](classic/security/)
#
# ## Notes
# - Jupyter is configured with `lessons/` as the file-browser root.
# - To include the classic kernel, rebuild with `make notebooks-build-classic`.
# - You can still open the regular Launcher with `File -> New Launcher`.
