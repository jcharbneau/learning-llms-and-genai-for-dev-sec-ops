# %% [markdown]
# # 01 Token Counting (Modern 2026)
#
# Modern equivalent of `lessons/operations/01-token-counting-classic.ipynb`.
# This version uses current Runnable/LCEL style (`prompt | model`) and `invoke()` patterns.

# %%
import os
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

HAS_OPENAI = bool(os.getenv("OPENAI_API_KEY"))
print(f"OPENAI_API_KEY configured: {HAS_OPENAI}")

# %%
if not HAS_OPENAI:
    print("Skipping: OPENAI_API_KEY is not set.")
else:
    model = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
    prompt = ChatPromptTemplate.from_template("Return exactly 3 short bullets on why token counting matters in production.")
    chain = prompt | model
    result = chain.invoke({})
    print(result.content if hasattr(result, 'content') else result)

# %% [markdown]
# ## Comparison Notes
# - Classic notebooks are preserved with `-classic` in the filename.
# - This track keeps the same teaching goal but uses current LangChain-era patterns.
