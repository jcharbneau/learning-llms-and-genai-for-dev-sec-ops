# %% [markdown]
# # Quick Start: 2026 LiteLLM Track
#
# Provider routing, reliability, governance, and observability.
#
# ## Lesson Cards
#
# | Lesson | Open |
# |---|---|
# | 01 Provider Routing And Fallback | [Open](01-provider-routing-and-fallback.ipynb) |
# | 02 Cost Latency Routing | [Open](02-cost-latency-routing.ipynb) |
# | 03 Retries Timeouts Circuit Breakers | [Open](03-retries-timeouts-circuit-breakers.ipynb) |
# | 04 Structured Output Portability | [Open](04-structured-output-portability.ipynb) |
# | 05 Caching And Idempotency | [Open](05-caching-and-idempotency.ipynb) |
# | 06 Observability And Metrics | [Open](06-observability-and-metrics.ipynb) |
# | 07 Failure Drills | [Open](07-failure-drills.ipynb) |
# | 08 Security Governance | [Open](08-security-governance.ipynb) |
#
# ## Return
#
# Back to [2026 Ecosystem Index](../00-ecosystem-index.ipynb)
# Back to [Lessons Home](../../00-home.ipynb)
