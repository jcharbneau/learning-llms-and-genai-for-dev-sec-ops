# %% [markdown]
# # Quick Start: 2026 DSPy Track
#
# Typed programs, optimization loops, and release gates.
#
# ## Lesson Cards
#
# | Lesson | Open |
# |---|---|
# | 01 Signatures And Programs | [Open](01-signatures-and-programs.ipynb) |
# | 02 Composable Modules | [Open](02-composable-modules.ipynb) |
# | 03 Optimizers And Training Sets | [Open](03-optimizers-and-training-sets.ipynb) |
# | 04 Constraints And Structured Output | [Open](04-constraints-and-structured-output.ipynb) |
# | 05 Tool Augmented Programs | [Open](05-tool-augmented-programs.ipynb) |
# | 06 Regression Testing | [Open](06-regression-testing.ipynb) |
# | 07 Error Analysis Loop | [Open](07-error-analysis-loop.ipynb) |
# | 08 Production Hand Off | [Open](08-production-hand-off.ipynb) |
#
# ## Return
#
# Back to [2026 Ecosystem Index](../00-ecosystem-index.ipynb)
# Back to [Lessons Home](../../00-home.ipynb)
