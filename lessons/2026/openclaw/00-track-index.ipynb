# %% [markdown]
# # Quick Start: 2026 OpenClaw Track
#
# Gateway usage, routing, integrations, and production hardening for OpenClaw.
#
# ## Lesson Cards
#
# | Lesson | Open |
# |---|---|
# | 01 Shell Usage | [Open](01-shell-usage.ipynb) |
# | 02 Foundations Gateway Models | [Open](02-foundations-gateway-models.ipynb) |
# | 03 Provider Routing And Failover | [Open](03-provider-routing-and-failover.ipynb) |
# | 04 Channel Routing And Session Boundaries | [Open](04-channel-routing-and-session-boundaries.ipynb) |
# | 05 Web Tools And Browser Automation | [Open](05-web-tools-and-browser-automation.ipynb) |
# | 06 Skills And Clawhub Lifecycle | [Open](06-skills-and-clawhub-lifecycle.ipynb) |
# | 07 Cron And Webhook Automations | [Open](07-cron-and-webhook-automations.ipynb) |
# | 08 Showcase Integration Patterns | [Open](08-showcase-integration-patterns.ipynb) |
# | 09 Production Hardening And Release Gates | [Open](09-production-hardening-and-release-gates.ipynb) |
#
# ## Return
#
# Back to [2026 Ecosystem Index](../00-ecosystem-index.ipynb)
# Back to [Lessons Home](../../00-home.ipynb)
