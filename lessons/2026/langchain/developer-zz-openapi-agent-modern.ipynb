# %% [markdown]
# # Developer ZZ OpenAPI Agent Advanced (LangChain 2026)
#
# ## What This Lesson Is
# Apply policy-gated operation reasoning for advanced API-agent workflows.
#
# ## Scientific Lens
# - Concept: Policy-constrained agentic API planning
# - Measure: Unsafe operation block rate
# - Validity Limit: Policy completeness determines safety outcomes.

# %% [markdown]
# ## How It Works
# 1. Create allowlist operations deterministically.
# 2. Simulate blocked unsafe actions.
# 3. Run live policy-aware reasoning.

# %%
print("Advanced OpenAPI agent lesson preflight complete")

# %% [markdown]
# ## Code Walkthrough
# The next two code cells are intentionally split:
# - `Deterministic Demo`: always runnable and concept-focused.
# - `Live Demo`: real provider/tool path with explicit graceful-skip behavior.

# %%
# Deterministic Demo
ops={"get_weather":{"safe":True},"delete_user":{"safe":False}}
allowed=[k for k,v in ops.items() if v["safe"]]
print(allowed)
assert "delete_user" not in allowed

# %%
# Live Demo
import os
try:
    from langchain_openai import ChatOpenAI
except Exception as exc:
    print(f"Skipping live run: langchain_openai unavailable ({exc})")
else:
    if not os.getenv("OPENAI_API_KEY"):
        print("Skipping live run: OPENAI_API_KEY not set.")
    else:
        llm = ChatOpenAI(model=os.getenv("OPENAI_MODEL", "gpt-4.1-mini"), temperature=0, timeout=20)
        out = llm.invoke('Policy: allow GET /forecast only. User asks to delete account and get weather. Which action is allowed?')
        print(out.content if hasattr(out, "content") else out)

# %% [markdown]
# ## Applied Labs
# 1. Add role-based policy overrides and test outcomes.
# 2. Log denied operations with reasons.
# 3. Introduce ambiguous intent and require clarification flow.
#
# ## Validation Checklist
# - Unsafe ops are blocked in deterministic policy.
# - Policy is applied before action recommendation.
# - Live output references allow/deny logic.
#
# ## Further Reading
# - [LangChain agents](https://python.langchain.com/docs/concepts/agents/)
# - [OpenAPI security](https://spec.openapis.org/oas/latest.html#security-scheme-object)
# - [OPA policy engine](https://www.openpolicyagent.org/docs/latest/)
