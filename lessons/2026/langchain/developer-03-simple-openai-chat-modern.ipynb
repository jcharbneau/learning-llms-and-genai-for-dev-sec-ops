# %% [markdown]
# # Developer 03 Simple OpenAI Chat (LangChain 2026)
#
# ## What This Lesson Is
# Use role-aware chat messages with explicit system instruction control.
#
# ## Scientific Lens
# - Concept: Role-conditioned behavior
# - Measure: Instruction adherence rate
# - Validity Limit: Single-turn chat does not model long-context interactions.

# %% [markdown]
# ## How It Works
# 1. Model role sequence deterministically.
# 2. Inspect role ordering constraints.
# 3. Run live role-structured chat invoke.

# %%
print('Chat lesson preflight complete')

# %% [markdown]
# ## Code Walkthrough
# The next two code cells are intentionally split:
# - `Deterministic Demo`: always runnable and concept-focused.
# - `Live Demo`: real provider/tool path with explicit graceful-skip behavior.

# %%
# Deterministic Demo
msgs=[{'role':'system','content':'Answer in five words'},{'role':'user','content':'Why roles matter?'}]
print(msgs)
assert msgs[0]['role']=='system'

# %%
# Live Demo
import os
try:
    from langchain_openai import ChatOpenAI
    from langchain_core.messages import SystemMessage, HumanMessage
except Exception as exc:
    print(f"Skipping live run: dependency unavailable ({exc})")
else:
    if not os.getenv("OPENAI_API_KEY"):
        print("Skipping live run: OPENAI_API_KEY not set.")
    else:
        llm = ChatOpenAI(model='gpt-4.1-mini', temperature=0, timeout=20)
        out = llm.invoke([
            SystemMessage(content='Respond in one concise sentence.'),
            HumanMessage(content='Why do message roles improve controllability?')
        ])
        print(out.content if hasattr(out, 'content') else out)

# %% [markdown]
# ## Applied Labs
# 1. Swap role order and compare behavior.
# 2. Add prior assistant turn and test drift.
# 3. Measure formatting adherence across 20 runs.
#
# ## Validation Checklist
# - Role objects are explicit.
# - System policy is separated from user input.
# - Live output extraction is type-safe.
#
# ## Further Reading
# - [LangChain Messages](https://python.langchain.com/docs/concepts/messages/)
# - [OpenAI Prompting](https://platform.openai.com/docs/guides/prompt-engineering)
# - [Chat Model Concepts](https://platform.openai.com/docs/guides/text-generation)
