# %% [markdown]
# # Developer 10 API Chain OpenAPI (LangChain 2026)
#
# ## What This Lesson Is
# Use OpenAPI context to drive safe API request construction.
#
# ## Scientific Lens
# - Concept: Spec-grounded API reasoning
# - Measure: Correct operation selection rate
# - Validity Limit: Spec-correct planning can still fail at runtime auth/state.

# %% [markdown]
# ## How It Works
# 1. Parse operation options.
# 2. Apply operation policy constraints.
# 3. Run live spec-guided reasoning.

# %%
print("OpenAPI chain lesson preflight complete")

# %% [markdown]
# ## Code Walkthrough
# The next two code cells are intentionally split:
# - `Deterministic Demo`: always runnable and concept-focused.
# - `Live Demo`: real provider/tool path with explicit graceful-skip behavior.

# %%
# Deterministic Demo
spec={"/forecast":{"get":["lat","lon"]},"/alerts":{"get":["region"]}}
query="get forecast for brussels"
chosen="/forecast" if "forecast" in query else "/alerts"
print(chosen,spec[chosen])
assert chosen=="/forecast"

# %%
# Live Demo
import os
try:
    from langchain_openai import ChatOpenAI
except Exception as exc:
    print(f"Skipping live run: langchain_openai unavailable ({exc})")
else:
    if not os.getenv("OPENAI_API_KEY"):
        print("Skipping live run: OPENAI_API_KEY not set.")
    else:
        llm = ChatOpenAI(model=os.getenv("OPENAI_MODEL", "gpt-4.1-mini"), temperature=0, timeout=20)
        out = llm.invoke('Given API operation GET /forecast(lat,lon), describe a safe request for Brussels in one sentence.')
        print(out.content if hasattr(out, "content") else out)

# %% [markdown]
# ## Applied Labs
# 1. Add one mutating endpoint and enforce deny policy.
# 2. Validate required params before operation selection.
# 3. Create ambiguous query set and require clarification.
#
# ## Validation Checklist
# - Operation selection logic is explicit.
# - Unsafe operations can be blocked by policy.
# - Live output references API contract terms.
#
# ## Further Reading
# - [OpenAPI Spec](https://spec.openapis.org/oas/latest.html)
# - [LangChain Tools](https://python.langchain.com/docs/concepts/tools/)
# - [HTTP Semantics](https://www.rfc-editor.org/rfc/rfc9110.html)
