# %% [markdown]
# # Developer 12 CrewAI-style Role Workflow (LangChain 2026)
#
# ## What This Lesson Is
# Decompose tasks into role-specific stages with verifiable handoffs.
#
# ## Scientific Lens
# - Concept: Role-oriented workflow decomposition
# - Measure: Handoff completeness
# - Validity Limit: Role pipelines may hide cross-stage coupling risks.

# %% [markdown]
# ## How It Works
# 1. Define role matrix.
# 2. Validate stage outputs.
# 3. Run live role-sequenced generation.

# %%
print("Role workflow lesson preflight complete")

# %% [markdown]
# ## Code Walkthrough
# The next two code cells are intentionally split:
# - `Deterministic Demo`: always runnable and concept-focused.
# - `Live Demo`: real provider/tool path with explicit graceful-skip behavior.

# %%
# Deterministic Demo
roles={"researcher":"facts","analyst":"synthesis","reviewer":"verification"}
flow=["researcher","analyst","reviewer"]
print(roles,flow)
assert flow[-1]=="reviewer"

# %%
# Live Demo
import os
try:
    from langchain_openai import ChatOpenAI
except Exception as exc:
    print(f"Skipping live run: langchain_openai unavailable ({exc})")
else:
    if not os.getenv("OPENAI_API_KEY"):
        print("Skipping live run: OPENAI_API_KEY not set.")
    else:
        llm = ChatOpenAI(model=os.getenv("OPENAI_MODEL", "gpt-4.1-mini"), temperature=0, timeout=20)
        out = llm.invoke('Act as reviewer after researcher and analyst stages. In one sentence, state one verification criterion for their output.')
        print(out.content if hasattr(out, "content") else out)

# %% [markdown]
# ## Applied Labs
# 1. Add required handoff schema fields per role.
# 2. Track contradiction rate between analyst and reviewer outputs.
# 3. Apply cost budget per role stage.
#
# ## Validation Checklist
# - Roles are distinct and ordered.
# - Handoff expectations are explicit.
# - Live output references reviewer/verification intent.
#
# ## Further Reading
# - [CrewAI Docs](https://docs.crewai.com/)
# - [LangChain Agent Patterns](https://python.langchain.com/docs/concepts/agents/)
# - [Multi-agent survey](https://arxiv.org/abs/2308.08155)
