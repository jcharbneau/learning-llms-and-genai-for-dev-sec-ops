# %% [markdown]
# # Quality 01 LangSmith Evaluations (LangChain 2026)
#
# ## What This Lesson Is
# Score outputs with explicit rubric and trace evaluation context.
#
# ## Scientific Lens
# - Concept: Evaluation-driven quality control
# - Measure: Rubric pass rate
# - Validity Limit: Rubrics are only as good as dataset representativeness.

# %% [markdown]
# ## How It Works
# 1. Define deterministic rubric scoring.
# 2. Evaluate sample outputs.
# 3. Run live generation with eval-ready context.

# %%
import os
print("LANGCHAIN_API_KEY configured:", bool(os.getenv("LANGCHAIN_API_KEY")))
print("OPENAI_API_KEY configured:", bool(os.getenv("OPENAI_API_KEY")))

# %% [markdown]
# ## Code Walkthrough
# The next two code cells are intentionally split:
# - `Deterministic Demo`: always runnable and concept-focused.
# - `Live Demo`: real provider/tool path with explicit graceful-skip behavior.

# %%
# Deterministic Demo
rubric={"factual":0.5,"concise":0.25,"actionable":0.25}
candidate={"factual":1,"concise":1,"actionable":0}
score=sum(rubric[k]*candidate[k] for k in rubric)
print(score)
assert 0<=score<=1

# %%
# Live Demo
import os
try:
    from langchain_openai import ChatOpenAI
except Exception as exc:
    print(f"Skipping live run: langchain_openai unavailable ({exc})")
else:
    if not os.getenv("OPENAI_API_KEY"):
        print("Skipping live run: OPENAI_API_KEY not set.")
    else:
        llm = ChatOpenAI(model=os.getenv("OPENAI_MODEL", "gpt-4.1-mini"), temperature=0, timeout=20)
        out = llm.invoke('Answer concisely: why explicit evaluation rubrics improve model quality governance.')
        print(out.content if hasattr(out, "content") else out)

# %% [markdown]
# ## Applied Labs
# 1. Add domain-specific rubric dimensions and weights.
# 2. Compare prompt variants by rubric score deltas.
# 3. Persist evaluation history and detect regressions.
#
# ## Validation Checklist
# - Rubric is explicit and weighted.
# - Score calculation is reproducible.
# - Live output can be traced when LangSmith env is set.
#
# ## Further Reading
# - [LangSmith evals](https://docs.smith.langchain.com/evaluation)
# - [LangChain evaluation concepts](https://python.langchain.com/docs/concepts/evaluation/)
# - [Measurement basics](https://en.wikipedia.org/wiki/Measurement)
