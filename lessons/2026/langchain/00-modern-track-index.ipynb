# %% [markdown]
# # Quick Start: 2026 LangChain (Modern)
#
# Runnable/LCEL-first modern LangChain lessons.
#
# ## Lesson Cards
#
# | Lesson | Open |
# |---|---|
# | Developer 01 Simple Openai Llm Modern | [Open](developer-01-simple-openai-llm-modern.ipynb) |
# | Developer 02 Simple Debugging Modern | [Open](developer-02-simple-debugging-modern.ipynb) |
# | Developer 03 Simple Openai Chat Modern | [Open](developer-03-simple-openai-chat-modern.ipynb) |
# | Developer 04 Simple Prompt Template Modern | [Open](developer-04-simple-prompt-template-modern.ipynb) |
# | Developer 09 Qachain Rag Modern | [Open](developer-09-qachain-rag-modern.ipynb) |
# | Developer 09 Rag Lcel Modern | [Open](developer-09-rag-lcel-modern.ipynb) |
# | Developer 10 Apichain Openapi Modern | [Open](developer-10-apichain-openapi-modern.ipynb) |
# | Developer 11 Agent With Search Tool Modern | [Open](developer-11-agent-with-search-tool-modern.ipynb) |
# | Developer 12 Crewai Modern | [Open](developer-12-crewai-modern.ipynb) |
# | Developer 14 Vision Modern | [Open](developer-14-vision-modern.ipynb) |
# | Developer Zz Openapi Agent Modern | [Open](developer-zz-openapi-agent-modern.ipynb) |
# | Operations 01 Token Counting Modern | [Open](operations-01-token-counting-modern.ipynb) |
# | Operations 02 Caching Lllm Modern | [Open](operations-02-caching-lllm-modern.ipynb) |
# | Operations 04 Local Llm Modern | [Open](operations-04-local-llm-modern.ipynb) |
# | Operations 06 Log Tofile Modern | [Open](operations-06-log-tofile-modern.ipynb) |
# | Operations 07 Parsing Retry Modern | [Open](operations-07-parsing-retry-modern.ipynb) |
# | Quality 01 Langsmith Evaluations Modern | [Open](quality-01-langsmith-evaluations-modern.ipynb) |
# | Security 01 Prompt Injection Modern | [Open](security-01-prompt-injection-modern.ipynb) |
# | Security 03 Prompt Injection Detector Prompt Modern | [Open](security-03-prompt-injection-detector-prompt-modern.ipynb) |
# | Security 04 Self Critique Modern | [Open](security-04-self-critique-modern.ipynb) |
# | Security 99  Todo Nemoguardrails Modern | [Open](security-99__todo-nemoguardrails-modern.ipynb) |
#
# ## Return
#
# Back to [2026 Ecosystem Index](../00-ecosystem-index.ipynb)
# Back to [Lessons Home](../../00-home.ipynb)
