# %% [markdown]
# # 2026 LangChain Modern Track
#
# This folder contains modern equivalents of the classic notebooks.
# Each notebook references its `-classic` source and uses LCEL/Runnable-first patterns.

# %% [markdown]
# ## Notebooks
# - `developer-01-simple-openai-llm-modern.ipynb` <- `lessons/classic/developer/01-simple-openai-llm-classic.ipynb`
# - `developer-02-simple-debugging-modern.ipynb` <- `lessons/classic/developer/02-simple-debugging-classic.ipynb`
# - `developer-03-simple-openai-chat-modern.ipynb` <- `lessons/classic/developer/03-simple-openai-chat-classic.ipynb`
# - `developer-04-simple-prompt-template-modern.ipynb` <- `lessons/classic/developer/04-simple-prompt-template-classic.ipynb`
# - `developer-09-qachain-rag-modern.ipynb` <- `lessons/classic/developer/09-qachain-rag-classic.ipynb`
# - `developer-09-rag-lcel-modern.ipynb` <- `lessons/classic/developer/09-rag-lcel-classic.ipynb`
# - `developer-10-apichain-openapi-modern.ipynb` <- `lessons/classic/developer/10-apichain-openapi-classic.ipynb`
# - `developer-11-agent-with-search-tool-modern.ipynb` <- `lessons/classic/developer/11-agent-with-search-tool-classic.ipynb`
# - `developer-12-crewai-modern.ipynb` <- `lessons/classic/developer/12-crewai-classic.ipynb`
# - `developer-14-vision-modern.ipynb` <- `lessons/classic/developer/14-vision-classic.ipynb`
# - `developer-zz-openapi-agent-modern.ipynb` <- `lessons/classic/developer/zz-openapi-agent-classic.ipynb`
# - `operations-01-token-counting-modern.ipynb` <- `lessons/classic/operations/01-token-counting-classic.ipynb`
# - `operations-02-caching-lllm-modern.ipynb` <- `lessons/classic/operations/02-caching-lllm-classic.ipynb`
# - `operations-04-local-llm-modern.ipynb` <- `lessons/classic/operations/04-local-llm-classic.ipynb`
# - `operations-06-log-tofile-modern.ipynb` <- `lessons/classic/operations/06-log-tofile-classic.ipynb`
# - `operations-07-parsing-retry-modern.ipynb` <- `lessons/classic/operations/07-parsing-retry-classic.ipynb`
# - `quality-01-langsmith-evaluations-modern.ipynb` <- `lessons/classic/quality/01-langsmith-evaluations-classic.ipynb`
# - `security-01-prompt-injection-modern.ipynb` <- `lessons/classic/security/01-prompt-injection-classic.ipynb`
# - `security-03-prompt-injection-detector-prompt-modern.ipynb` <- `lessons/classic/security/03-prompt-injection-detector-prompt-classic.ipynb`
# - `security-04-self-critique-modern.ipynb` <- `lessons/classic/security/04-self-critique-classic.ipynb`
# - `security-99__todo-nemoguardrails-modern.ipynb` <- `lessons/classic/security/99__todo-nemoguardrails-classic.ipynb`
