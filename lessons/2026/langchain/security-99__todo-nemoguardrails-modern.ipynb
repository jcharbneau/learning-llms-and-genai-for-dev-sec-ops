# %% [markdown]
# # Security 99 Nemo Guardrails TODO (LangChain 2026)
#
# ## What This Lesson Is
# Define a guardrails integration scaffold with explicit staged policy checks.
#
# ## Scientific Lens
# - Concept: Guardrails architecture planning
# - Measure: Policy-stage coverage
# - Validity Limit: Scaffold is not a full framework integration.

# %% [markdown]
# ## How It Works
# 1. Define stage order deterministically.
# 2. Validate stage constraints.
# 3. Run live policy-gated placeholder flow.

# %%
print("Nemo guardrails TODO preflight complete")

# %% [markdown]
# ## Code Walkthrough
# The next two code cells are intentionally split:
# - `Deterministic Demo`: always runnable and concept-focused.
# - `Live Demo`: real provider/tool path with explicit graceful-skip behavior.

# %%
# Deterministic Demo
stages=["input_filter","policy_check","generation","self_critique","output_filter"]
print(stages)
assert stages.index("policy_check") < stages.index("generation")

# %%
# Live Demo
import os
try:
    from langchain_openai import ChatOpenAI
except Exception as exc:
    print(f"Skipping live guardrail scaffold run: dependency unavailable ({exc})")
else:
    if not os.getenv("OPENAI_API_KEY"):
        print("Skipping live guardrail scaffold run: OPENAI_API_KEY not set.")
    else:
        llm = ChatOpenAI(model='gpt-4.1-mini', temperature=0, timeout=20)
        user_input = 'Explain prompt-injection mitigation in one sentence.'
        if 'reveal secrets' in user_input.lower():
            print('blocked by policy')
        else:
            out = llm.invoke(user_input)
            print(out.content if hasattr(out, 'content') else out)

# %% [markdown]
# ## Applied Labs
# 1. Define concrete integration checklist for Nemo Guardrails.
# 2. Add policy test cases for each stage.
# 3. Create migration steps from scaffold to full integration.
#
# ## Validation Checklist
# - Policy check precedes generation stage.
# - Scaffold stages are explicit and ordered.
# - Live placeholder flow is safe and bounded.
#
# ## Further Reading
# - [NVIDIA NeMo Guardrails](https://docs.nvidia.com/nemo/guardrails/)
# - [LangChain guardrails](https://python.langchain.com/docs/concepts/guardrails/)
# - [OWASP LLM Top 10](https://owasp.org/www-project-top-10-for-large-language-model-applications/)
