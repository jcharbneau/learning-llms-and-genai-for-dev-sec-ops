# %% [markdown]
# # 2026 Ecosystem Lessons
#
# This index introduces non-LangChain libraries and agent runtimes used in 2026 workflows.
#
# - `litellm/01-provider-routing-and-fallback.ipynb`
# - `llamaindex/01-rag-minimal-modern.ipynb`
# - `dspy/01-signatures-and-programs.ipynb`
# - `agent-clis/01-opencode-codex-claudecode-playbook.ipynb`
