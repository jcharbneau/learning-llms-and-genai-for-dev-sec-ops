# %% [markdown]
# # Quick Start: 2026 Ecosystem
#
# Use this index to choose a modern 2026 track.
#
# ## Track Cards
#
# | Track | Focus | Open |
# |---|---|---|
# | LangChain (Modern) | Modern LangChain runnable patterns and applied lessons. | [Open](langchain/00-modern-track-index.ipynb) |
# | LiteLLM | Provider routing, reliability, portability, and controls. | [Open](litellm/00-track-index.ipynb) |
# | LlamaIndex | RAG architecture, retrieval quality, and lifecycle management. | [Open](llamaindex/00-track-index.ipynb) |
# | DSPy | Programmatic prompting, optimization, testing, and handoff. | [Open](dspy/00-track-index.ipynb) |
# | Agent CLIs | AI coding-agent operational practices and governance. | [Open](agent-clis/00-track-index.ipynb) |
# | OpenClaw | Gateway-centric integrations, routing, channels, and automation. | [Open](openclaw/00-track-index.ipynb) |
#
# ## Recommended Progression
#
# 1. Start with one core track (`LangChain` or `LiteLLM`).
# 2. Add one retrieval/program track (`LlamaIndex` or `DSPy`).
# 3. Add execution/governance tracks (`Agent CLIs`, `OpenClaw`).
#
# ## Return
#
# Back to [Lessons Home](../00-home.ipynb).
