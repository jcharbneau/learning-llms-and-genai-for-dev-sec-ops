# %% [markdown]
# # 2026 Ecosystem Lessons
#
# This index introduces 2026 lesson batches across LangChain and non-LangChain ecosystems.
#
# - `langchain/00-modern-track-index.ipynb`
# - `litellm/00-track-index.ipynb`
# - `llamaindex/00-track-index.ipynb`
# - `dspy/00-track-index.ipynb`
# - `agent-clis/00-track-index.ipynb`
# - `openclaw/00-track-index.ipynb`

# %% [markdown]
# ## Suggested Learning Order
# 1. LangChain modern track
# 2. LiteLLM
# 3. LlamaIndex
# 4. DSPy
# 5. Agent CLIs
# 6. OpenClaw
