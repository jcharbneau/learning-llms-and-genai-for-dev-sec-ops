# %% [markdown]
# # Quick Start: 2026 LlamaIndex Track
#
# RAG indexing, retrieval quality, and production tuning.
#
# ## Lesson Cards
#
# | Lesson | Open |
# |---|---|
# | 01 Rag Minimal Modern | [Open](01-rag-minimal-modern.ipynb) |
# | 02 Chunking And Metadata Strategy | [Open](02-chunking-and-metadata-strategy.ipynb) |
# | 03 Hybrid Retrieval | [Open](03-hybrid-retrieval.ipynb) |
# | 04 Reranking Pipeline | [Open](04-reranking-pipeline.ipynb) |
# | 05 Router Retrievers | [Open](05-router-retrievers.ipynb) |
# | 06 Evaluating Retrieval Quality | [Open](06-evaluating-retrieval-quality.ipynb) |
# | 07 Index Persistence Refresh | [Open](07-index-persistence-refresh.ipynb) |
# | 08 Cost Performance Tuning | [Open](08-cost-performance-tuning.ipynb) |
#
# ## Return
#
# Back to [2026 Ecosystem Index](../00-ecosystem-index.ipynb)
# Back to [Lessons Home](../../00-home.ipynb)
