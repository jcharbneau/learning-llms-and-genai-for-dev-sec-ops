# %% [markdown]
# # Quick Start: 2026 Agent CLIs Track
#
# Operational patterns for OpenCode, Codex, and Claude Code workflows.
#
# ## Lesson Cards
#
# | Lesson | Open |
# |---|---|
# | 01 Opencode Codex Claudecode Playbook | [Open](01-opencode-codex-claudecode-playbook.ipynb) |
# | 02 Safe Repo Mutation Workflow | [Open](02-safe-repo-mutation-workflow.ipynb) |
# | 03 Approval And Sandbox Policies | [Open](03-approval-and-sandbox-policies.ipynb) |
# | 04 Prompt To Pr Quality | [Open](04-prompt-to-pr-quality.ipynb) |
# | 05 Resilience Under Failure | [Open](05-resilience-under-failure.ipynb) |
# | 06 Security Posture Checks | [Open](06-security-posture-checks.ipynb) |
# | 07 Latency And Cost Benchmarking | [Open](07-latency-and-cost-benchmarking.ipynb) |
# | 08 Team Adoption Playbook | [Open](08-team-adoption-playbook.ipynb) |
#
# ## Return
#
# Back to [2026 Ecosystem Index](../00-ecosystem-index.ipynb)
# Back to [Lessons Home](../../00-home.ipynb)
