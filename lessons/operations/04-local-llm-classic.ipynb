# %% [markdown]
# As a developer you might want to run your own llm locally.
# There are multiple providers for this.
# In this example we'll use Ollama <https://ollama.ai/>
#
# What is interesting about that is that they have an interface similar to Dockerfiles but with a Modelfile.
# > Classic track note: This notebook demonstrates legacy/classic LangChain-era patterns for evaluation and comparison.
# > Prefer the modern equivalents in `lessons/2026-langchain/` for current APIs and recommended techniques.

# %% [markdown]
# ```
# Usage:
#   ollama [command]
#
# Available Commands:
#   serve       Start ollama
#   create      Create a model from a Modelfile
#   run         Run a model
#   pull        Pull a model from a registry
#   push        Push a model to a registry
#   list        List models
#   cp          Copy a model
#   rm          Remove a model
#   help        Help about any command
# ```

# %% [markdown]
# From https://github.com/jmorganca/ollama/blob/main/examples/devops-engineer/Modelfile
# ```
# Modelfile for creating a devops engineer assistant
# # Run `ollama create devops-engineer -f ./Modelfile` and then `ollama run devops-engineer` and enter a topic
#
# FROM llama2:13b
# PARAMETER temperature 1
# SYSTEM """
# You are a senior devops engineer, acting as an assistant. You offer help with cloud technologies like: Terraform, AWS, kubernetes, python. You answer with code examples when possible
# """
# ```

# %% [markdown]
# ```
# % ./ollama  list
# NAME                    	SIZE  	MODIFIED
# llama2:13b              	7.3 GB	3 weeks ago
# llama2:latest           	3.8 GB	3 weeks ago
# llama2-uncensored:latest	3.8 GB	3 weeks ago
# ```

# %%
# %pip install -q langchain langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We set up the usual boilerplate

# %%
# A bit of trickery to load the handler from a top directory
import sys
sys.path.append('../developer')
from _lessonshelper.pretty_print_callback_handler import PrettyPrintCallbackHandler
pretty_callback = PrettyPrintCallbackHandler()

# %% [markdown]
# To make a call similar to OpenAI we just instantiate from Ollama

# %%
#from langchain.llms import OpenAI
import os
from langchain_community.chat_models import ChatOllama

# for comparison
# llm = OpenAI()
ollama_model = os.getenv("OLLAMA_MODEL", "qwen2.5-coder:1.5b")
ollama_base_url = os.getenv("OLLAMA_BASE_URL", "http://host.docker.internal:11434")
print(f"Using OLLAMA_BASE_URL={ollama_base_url}")
llm = ChatOllama(model=ollama_model, base_url=ollama_base_url, temperature=0, callbacks=[pretty_callback])

llm.callbacks = [pretty_callback]

prompt = "What is DevOps ? Please be verbose and detailed in your answer."
result = llm.invoke(prompt)
# Out:
# Using OLLAMA_BASE_URL=http://host.docker.internal:11434
# [chat_model][start] - prompts : What is DevOps ? Please be verbose and detailed in your answer.
# [llm][new_token] Dev
# [llm][new_token] Ops
# [llm][new_token]  is
# [llm][new_token]  an
# [llm][new_token]  Agile
# [llm][new_token]  methodology
# [llm][new_token]  that
# [llm][new_token]  emphasizes
# [llm][new_token]  collaboration
# [llm][new_token]  between
# [llm][new_token]  development
# [llm][new_token]  and
# [llm][new_token]  operations
# [llm][new_token]  teams
# [llm][new_token]  to
# [llm][new_token]  deliver
# [llm][new_token]  software
# [llm][new_token]  products
# [llm][new_token]  faster
# [llm][new_token]  and
# [llm][new_token]  more
# [llm][new_token]  efficiently
# [llm][new_token] .
# [llm][new_token]  It
# [llm][new_token]  was
# [llm][new_token]  developed
# [llm][new_token]  in
# [llm][new_token]  the
# [llm][new_token]  late
# [llm][new_token]
# [llm][new_token] 1
# [llm][new_token] 9
# [llm][new_token] 9
# [llm][new_token] 0
# [llm][new_token] s
# [llm][new_token]  by
# [llm][new_token]  Ken
# [llm][new_token]  Schw
# [llm][new_token] aber
# [llm][new_token]  and
# [llm][new_token]  Jeff
# [llm][new_token]  S
# [llm][new_token] utherland
# [llm][new_token]  at
# [llm][new_token]  Microsoft
# [llm][new_token] ,
# [llm][new_token]  but
# [llm][new_token]  it
# [llm][new_token]  has
# [llm][new_token]  since
# [llm][new_token]  become
# [llm][new_token]  a
# [llm][new_token]  widely
# [llm][new_token]  adopted
# [llm][new_token]  practice
# [llm][new_token]  across
# [llm][new_token]  various
# [llm][new_token]  industries
# [llm][new_token] .
#
# [llm][new_token] At
# [llm][new_token]  its
# [llm][new_token]  core
# [llm][new_token] ,
# [llm][new_token]  Dev
# [llm][new_token] Ops
# [llm][new_token]  is
# [llm][new_token]  about
# [llm][new_token]  breaking
# [llm][new_token]  down
# [llm][new_token]  sil
# [llm][new_token] os
# [llm][new_token]  between
# [llm][new_token]  development
# [llm][new_token]  and
# [llm][new_token]  operations
# [llm][new_token]  teams
# [llm][new_token] ,
# [llm][new_token]  allowing
# [llm][new_token]  them
# [llm][new_token]  to
# [llm][new_token]  work
# [llm][new_token]  together
# [llm][new_token]  more
# [llm][new_token]  closely
# [llm][new_token] .
# [llm][new_token]  This
# [llm][new_token]  collaboration
# [llm][new_token]  involves
# [llm][new_token]  sharing
# [llm][new_token]  information
# [llm][new_token] ,
# [llm][new_token]  tools
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  processes
# [llm][new_token] ,
# [llm][new_token]  as
# [llm][new_token]  well
# [llm][new_token]  as
# [llm][new_token]  adopting
# [llm][new_token]  agile
# [llm][new_token]  practices
# [llm][new_token]  such
# [llm][new_token]  as
# [llm][new_token]  continuous
# [llm][new_token]  integration
# [llm][new_token]  (
# [llm][new_token] CI
# [llm][new_token] )
# [llm][new_token]  and
# [llm][new_token]  continuous
# [llm][new_token]  deployment
# [llm][new_token]  (
# [llm][new_token] CD
# [llm][new_token] ).
#
# [llm][new_token] One
# [llm][new_token]  of
# [llm][new_token]  the
# [llm][new_token]  key
# [llm][new_token]  benefits
# [llm][new_token]  of
# [llm][new_token]  Dev
# [llm][new_token] Ops
# [llm][new_token]  is
# [llm][new_token]  that
# [llm][new_token]  it
# [llm][new_token]  allows
# [llm][new_token]  organizations
# [llm][new_token]  to
# [llm][new_token]  deliver
# [llm][new_token]  software
# [llm][new_token]  products
# [llm][new_token]  faster
# [llm][new_token]  than
# [llm][new_token]  traditional
# [llm][new_token]  approaches
# [llm][new_token] .
# [llm][new_token]  By
# [llm][new_token]  autom
# [llm][new_token] ating
# [llm][new_token]  the
# [llm][new_token]  build
# [llm][new_token] ,
# [llm][new_token]  test
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  deployment
# [llm][new_token]  process
# [llm][new_token] ,
# [llm][new_token]  teams
# [llm][new_token]  can
# [llm][new_token]  reduce
# [llm][new_token]  the
# [llm][new_token]  time
# [llm][new_token]  it
# [llm][new_token]  takes
# [llm][new_token]  to
# [llm][new_token]  develop
# [llm][new_token]  and
# [llm][new_token]  deploy
# [llm][new_token]  new
# [llm][new_token]  features
# [llm][new_token]  or
# [llm][new_token]  bug
# [llm][new_token]  fixes
# [llm][new_token] .
#
# [llm][new_token] Another
# [llm][new_token]  benefit
# [llm][new_token]  of
# [llm][new_token]  Dev
# [llm][new_token] Ops
# [llm][new_token]  is
# [llm][new_token]  that
# [llm][new_token]  it
# [llm][new_token]  promotes
# [llm][new_token]  collaboration
# [llm][new_token]  between
# [llm][new_token]  development
# [llm][new_token]  and
# [llm][new_token]  operations
# [llm][new_token]  teams
# [llm][new_token] .
# [llm][new_token]  This
# [llm][new_token]  collaboration
# [llm][new_token]  involves
# [llm][new_token]  sharing
# [llm][new_token]  information
# [llm][new_token] ,
# [llm][new_token]  tools
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  processes
# [llm][new_token] ,
# [llm][new_token]  as
# [llm][new_token]  well
# [llm][new_token]  as
# [llm][new_token]  adopting
# [llm][new_token]  agile
# [llm][new_token]  practices
# [llm][new_token]  such
# [llm][new_token]  as
# [llm][new_token]  continuous
# [llm][new_token]  integration
# [llm][new_token]  (
# [llm][new_token] CI
# [llm][new_token] )
# [llm][new_token]  and
# [llm][new_token]  continuous
# [llm][new_token]  deployment
# [llm][new_token]  (
# [llm][new_token] CD
# [llm][new_token] ).
# [llm][new_token]  By
# [llm][new_token]  working
# [llm][new_token]  together
# [llm][new_token] ,
# [llm][new_token]  teams
# [llm][new_token]  can
# [llm][new_token]  identify
# [llm][new_token]  and
# [llm][new_token]  fix
# [llm][new_token]  issues
# [llm][new_token]  more
# [llm][new_token]  quickly
# [llm][new_token] ,
# [llm][new_token]  leading
# [llm][new_token]  to
# [llm][new_token]  better
# [llm][new_token]  software
# [llm][new_token]  quality
# [llm][new_token]  and
# [llm][new_token]  customer
# [llm][new_token]  satisfaction
# [llm][new_token] .
#
# [llm][new_token] Dev
# [llm][new_token] Ops
# [llm][new_token]  also
# [llm][new_token]  emphasizes
# [llm][new_token]  the
# [llm][new_token]  importance
# [llm][new_token]  of
# [llm][new_token]  monitoring
# [llm][new_token]  and
# [llm][new_token]  logging
# [llm][new_token] .
# [llm][new_token]  By
# [llm][new_token]  collecting
# [llm][new_token]  data
# [llm][new_token]  on
# [llm][new_token]  system
# [llm][new_token]  performance
# [llm][new_token]  and
# [llm][new_token]  user
# [llm][new_token]  behavior
# [llm][new_token] ,
# [llm][new_token]  organizations
# [llm][new_token]  can
# [llm][new_token]  identify
# [llm][new_token]  potential
# [llm][new_token]  issues
# [llm][new_token]  before
# [llm][new_token]  they
# [llm][new_token]  become
# [llm][new_token]  major
# [llm][new_token]  problems
# [llm][new_token] .
# [llm][new_token]  This
# [llm][new_token]  allows
# [llm][new_token]  teams
# [llm][new_token]  to
# [llm][new_token]  take
# [llm][new_token]  corrective
# [llm][new_token]  action
# [llm][new_token]  before
# [llm][new_token]  a
# [llm][new_token]  problem
# [llm][new_token]  occurs
# [llm][new_token] ,
# [llm][new_token]  reducing
# [llm][new_token]  downtime
# [llm][new_token]  and
# [llm][new_token]  improving
# [llm][new_token]  customer
# [llm][new_token]  satisfaction
# [llm][new_token] .
#
# [llm][new_token] Overall
# [llm][new_token] ,
# [llm][new_token]  Dev
# [llm][new_token] Ops
# [llm][new_token]  is
# [llm][new_token]  an
# [llm][new_token]  Agile
# [llm][new_token]  methodology
# [llm][new_token]  that
# [llm][new_token]  promotes
# [llm][new_token]  collaboration
# [llm][new_token]  between
# [llm][new_token]  development
# [llm][new_token]  and
# [llm][new_token]  operations
# [llm][new_token]  teams
# [llm][new_token] ,
# [llm][new_token]  autom
# [llm][new_token] ates
# [llm][new_token]  the
# [llm][new_token]  build
# [llm][new_token] ,
# [llm][new_token]  test
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  deployment
# [llm][new_token]  process
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  emphasizes
# [llm][new_token]  monitoring
# [llm][new_token]  and
# [llm][new_token]  logging
# [llm][new_token] .
# [llm][new_token]  By
# [llm][new_token]  adopting
# [llm][new_token]  Dev
# [llm][new_token] Ops
# [llm][new_token] ,
# [llm][new_token]  organizations
# [llm][new_token]  can
# [llm][new_token]  deliver
# [llm][new_token]  software
# [llm][new_token]  products
# [llm][new_token]  faster
# [llm][new_token]  and
# [llm][new_token]  more
# [llm][new_token]  efficiently
# [llm][new_token] ,
# [llm][new_token]  leading
# [llm][new_token]  to
# [llm][new_token]  better
# [llm][new_token]  customer
# [llm][new_token]  satisfaction
# [llm][new_token]  and
# [llm][new_token]  improved
# [llm][new_token]  business
# [llm][new_token]  outcomes
# [llm][new_token] .
# [llm][new_token]
#
# =============
# [llm][end] - generation DevOps is an Agile methodology that emphasizes collaboration between development and operations teams to deliver software products faster and more efficiently. It was developed in the late 1990s by Ken Schwaber and Jeff Sutherland at Microsoft, but it has since become a widely adopted practice across various industries.
# At its core, DevOps is about breaking down silos between development and operations teams, allowing them to work together more closely. This collaboration involves sharing information, tools, and processes, as well as adopting agile practices such as continuous integration (CI) and continuous deployment (CD).
# One of the key benefits of DevOps is that it allows organizations to deliver software products faster than traditional approaches. By automating the build, test, and deployment process, teams can reduce the time it takes to develop and deploy new features or bug fixes.
# Another benefit of DevOps is that it promotes collaboration between development and operations teams. This collaboration involves sharing information, tools, and processes, as well as adopting agile practices such as continuous integration (CI) and continuous deployment (CD). By working together, teams can identify and fix issues more quickly, leading to better software quality and customer satisfaction.
# DevOps also emphasizes the importance of monitoring and logging. By collecting data on system performance and user behavior, organizations can identify potential issues before they become major problems. This allows teams to take corrective action before a problem occurs, reducing downtime and improving customer satisfaction.
# Overall, DevOps is an Agile methodology that promotes collaboration between development and operations teams, automates the build, test, and deployment process, and emphasizes monitoring and logging. By adopting DevOps, organizations can deliver software products faster and more efficiently, leading to better customer satisfaction and improved business outcomes.
